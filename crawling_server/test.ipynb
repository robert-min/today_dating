# %%
# -*- coding: utf-8 -*-
import errno
import urllib.request
import urllib.error
import urllib.parse
import json
import math
from bs4 import BeautifulSoup
import time
import secret
from collections import defaultdict


# 네이버 API
client_id = secret.naver_id
client_secret = secret.naver_secret

def get_blog_count(query, display):
    # OO 데이트로 기본 검색
    encode_query = urllib.parse.quote(query + '데이트')
    search_url = "https://openapi.naver.com/v1/search/blog?query=" + encode_query
    request = urllib.request.Request(search_url)

    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)

    response = urllib.request.urlopen(request)
    response_code = response.getcode()

    if (response_code == 200):
        response_body = response.read()
        response_body_dict = json.loads(response_body.decode("utf-8"))

        print("Last blog build date : " + str(response_body_dict["lastBuildDate"]))

        if response_body_dict["total"] == 0:
            blog_count = 0
        else:
            blog_total = math.ceil(response_body_dict["total"] / int(display))

            if blog_total >= 1000:
                blog_count = 1000
            else:
                blog_count = blog_total

            print("Blog total : " + str(blog_total))
            print("Blog count : " + str(blog_count))

    return blog_count


def get_blog_post(query, display, start_index):
    # OO 데이트로 기본 검색
    encode_query = urllib.parse.quote(query + ' 데이트')
    search_url = "https://openapi.naver.com/v1/search/blog?query=" + encode_query + \
                 "&start=" + str(start_index) + "&display=" + str(display)
    request = urllib.request.Request(search_url)

    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)

    response = urllib.request.urlopen(request)
    response_code = response.getcode()

    all_contents = defaultdict(list)

    if (response_code == 200):
        response_body = response.read()
        response_body_dict = json.loads(response_body.decode("utf-8"))
        print(response_body_dict)
        contents = response_body_dict["items"]
        all_contents["blog"] = contents
        all_place = list()

        for item_index in range(0, len(contents)):
            link = contents[item_index]["link"]
            ori_link = link.replace("?Redirect=Log&logNo=", "/")
            post_code = urllib.request.urlopen(ori_link).read()
            post_soup = BeautifulSoup(post_code, "lxml")

            for mainFrame in post_soup.select("iframe#mainFrame"):
                blog_post_url = "http://blog.naver.com" + mainFrame.get("src")
                blog_post_code = urllib.request.urlopen(blog_post_url).read()
                blog_post_soup = BeautifulSoup(blog_post_code, "lxml")

                try:
                    map_soup = blog_post_soup.find("div", attrs={"class" : "se-module se-module-map-text"})
                    place_text = map_soup.find("a")["data-linkdata"]
                    place_dict = json.loads(place_text)
                    all_place.append(place_dict)

                except:
                    pass
            item_index += 1
            time.sleep(0.1)

        all_contents["place"] = all_place

    return all_contents

test_contents = get_blog_post("용답", 100, 1)
test_contents
# Out:
# {'lastBuildDate': 'Tue, 19 Apr 2022 18:56:23 +0900', 'total': 472, 'start': 1, 'display': 100, 'items': [{'title': '답십리 해장국 맛집 장성식당과 <b>용답</b>카페 부루커피', 'link': 'https://blog.naver.com/clf123?Redirect=Log&logNo=222525733111', 'description': '그리고 용답역 바로 앞에 있는 청계천 앞에 벤치에서 천변 즐기며 부루커피 진짜 맛나게 먹었어요 !! 딱 답십리 데이트코스 - <b>용답데이트</b>코스로 좋은듯합니다! 서울여행와서 묵은 청량리호텔인 더 디자이너스... ', 'bloggername': '내 속엔 내가 너무도 많아', 'bloggerlink': 'https://blog.naver.com/clf123', 'postdate': '20211004'}, {'title': '서울, 매화 여행은 <b>용답</b>역 청계천 매화거리로', 'link': 'https://blog.naver.com/yo_onji?Redirect=Log&logNo=222686137521', 'description': '걷다보면 보이는 홍매화 ♥️ 대나무와 함께 피어있는데 색이 참 예뻤어요 ! 대나무도 푸릇푸릇 넘 예뻤구용 쉴수 있게 벤치도 있었어용! <b>데이트</b>나 산책으로 <b>용답</b>역 매화거리, 청계천 매화거리 추천드려요', 'bloggername': 'MY world', 'bloggerlink': 'https://blog.naver.com/yo_onji', 'postdate': '20220329'}, {'title': '서울 매화 명소 : <b>용답</b>역 청계천 하동매실거리 (ft. 개화 정도... ', 'link': 'https://blog.naver.com/bluesspace?Redirect=Log&logNo=222678216282', 'description': '서울 매화 명소: <b>용답</b>역 청계천 하동매실거리 (ft. 개화 정도, 위치) 안녕하세요! 얼마 전 뉴스에서... 대포 카메라를 든 분들도 사진 찍으러 많이 오셨고, <b>데이트</b>하는 분들도 서로 사진 찍어주고 계시고... ', 'bloggername': '매일 한걸음씩 꾸준히.', 'bloggerlink': 'https://blog.naver.com/bluesspace', 'postdate': '20220321'}, {'title': '서울 매화꽃 <b>용답</b>역 하동매실거리 서울 봄꽃 봄나들이 가볼만한곳', 'link': 'https://blog.naver.com/june_be?Redirect=Log&logNo=222686132451', 'description': '그래도 꼭 한 번은 가보고 싶어서 지난 3/26일 다녀온 <b>용답</b>역 하동매실거리 아마 지금쯤은 더 만개했을... 2호선 <b>용답</b>역에서 바로 연결되어 있다. <b>용답</b>역 2번출구 이용. 역 밖으로 나가서 <b>용답</b>역에서 신답역까지... ', 'bloggername': '오늘도 밝음♡', 'bloggerlink': 'https://blog.naver.com/june_be', 'postdate': '20220329'}, {'title': '<b>데이트</b>ㅣ한남동에서 따릉이타고 <b>용답</b>역까지', 'link': 'https://blog.naver.com/dmsgml094?Redirect=Log&logNo=222412047814', 'description': '#테이블링 앱 너무 편하다 다 먹구 한남역 쪽으로 올라가면 한강이 나오는데, 따릉이 빌려서 한강 라이딩 시작 댕댕이 하이 그림이 너무 귀여워서 원래 목표는 동네까지 가눈거였는데 2분의1 가구 포기:( <b>용답</b>역... ', 'bloggername': '평범한 일상 속 끄적끄적', 'bloggerlink': 'https://blog.naver.com/dmsgml094', 'postdate': '20210627'}, {'title': '<b>용답</b>깨비곱창은 <b>용답</b>역모임,<b>데이트</b>에 딱입니다.', 'link': 'https://blog.naver.com/wjddkssk62?Redirect=Log&logNo=221591325559', 'description': '#<b>용답</b>역곱창 #<b>용답</b>역모임 #<b>용답</b>역<b>데이트</b> #<b>용답</b>곱창 #<b>용답</b>곱창맛집 주소: 서울성동구 <b>용답</b>19길 5 예약번호:02-3394-6595 동생이랑 남편이랑 청계천<b>데이트</b>를 자주는데요~ 마장에서 <b>용답</b>역으로 가는 청계천길이 너무... ', 'bloggername': '아따맘띠의 wedding story ♡', 'bloggerlink': 'https://blog.naver.com/wjddkssk62', 'postdate': '20190721'}, {'title': '<b>용답</b>역맛집 모듬 1인분 10,000원 서울 최고의 가성비 소곱창... ', 'link': 'https://blog.naver.com/rony_02?Redirect=Log&logNo=222699486873', 'description': '여기는 술이 술+술+술 들어가는곳ㅋㅋ <b>용답</b>역 근처에서 술 약속 있으신 분들, 모임이나 <b>데이트</b>하시는 분들 추천드릴게요 #왕십리곱창 #왕십리소곱창 #소곱창 #곱창맛집 #곱창막창 #곱창대창막창 #수입소곱창... ', 'bloggername': 'rony_planet', 'bloggerlink': 'https://blog.naver.com/rony_02', 'postdate': '20220413'}, {'title': '하동 매실거리와 도깨비 촬영지인 <b>용답</b>역에 가보다', 'link': 'https://blog.naver.com/merry_jung?Redirect=Log&logNo=222292697952', 'description': '서울 <b>데이트</b>를 즐기기 좋은 코스입니다. 연인 둘이서 손잡고 걸어도 좋고 사진 가볍게 남기기 괜찮은 곳! 2호선 성수역에서 내려 갈아타서 <b>용답</b>에서 내렸습니다. 대략적으로 위치가 한양대학교 캠퍼스 뒤... ', 'bloggername': '혜윰 트래블 모먼트❤️', 'bloggerlink': 'https://blog.naver.com/merry_jung', 'postdate': '20210330'}, {'title': '청계천 매화거리(하동매실거리)  <b>용답</b>역 매화 곱게 피네요... ', 'link': 'https://blog.naver.com/hari33?Redirect=Log&logNo=222682087928', 'description': '#청계천매화거리 #하동매실거리 #<b>용답</b>역매화 #서울꽃구경 #매화와새 회사 일정이 좀 일찍 끝나서 <b>용답</b>역 매화 보러 청계천매화거리 다녀왔어요~^^* 막내와 <b>용답</b>역에서 만나 즐거운 서울꽃구경 <b>데이트</b>해서 좋던... ', 'bloggername': '엄마의 꿈&여행 - story 2', 'bloggerlink': 'https://blog.naver.com/hari33', 'postdate': '20220324'}, {'title': "서울<b>데이트</b> <b>용답</b>역 드라마 '도깨비' 촬영지", 'link': 'https://blog.naver.com/season1810?Redirect=Log&logNo=221194998574', 'description': '여기도 <b>용답</b>역 육교예요ㅎㅎㅎㅎ 드라마 촬영지로도 유명하지만 또한 <b>데이트</b> 장소로도 적정한 <b>용답</b>역 육교를 한 번 가보도록 할께요!! <b>용답</b>역은 성수역에서 신설동 사이를 운행하는 2호선을 타야갈 수가 있어요... ', 'bloggername': '캐시의일기장', 'bloggerlink': 'https://blog.naver.com/season1810', 'po ...
# defaultdict(list, {})

# %%
from time import time, localtime, strftime

tm = localtime(time())
strftime("%Y-%m-%d", tm)
# Out:
# '2022-04-19'

# %%
import json
import os
from time import time, localtime, strftime

tm = localtime(time())
strftime("%Y-%m-%d", tm)

path = "./date_data/"+ strftime("%Y-%m-%d", tm)

try:
    if not os.path.isdir(path):
        os.mkdir(path)
except OSError as e:
    if e.errno != e.errno.EEXIST:
        print("Failed to create")
        raise

with open(path + "/test2.json", "w") as f:
    json.dump(test_contents, f, indent=4, ensure_ascii=False)

# %%
def save_parquet(query, display, start_index):
    data = get_blog_post(query, display, start_index)

    from pyspark.sql import SparkSession

    MAX_MEMORY = "5g"
    spark = SparkSession.builder.appName("today_dating") \
        .config("spark.executor.memory", MAX_MEMORY) \
        .config("spark.driver.memory", MAX_MEMORY) \
        .getOrCreate()

    df = spark.createDataFrame(data, schema=None)
    df.write.json("./")

    print("수집완료")

if __name__ == '__main__':
    query = ["용답"]
    display = 100
    start = 1
    for q in query:
        blog_count = get_blog_count(q, display)
        for start_index in range(start, blog_count + 1, display):
            print(start_index)
            save_parquet(q, display, start_index)
            print()

# %%
import boto3
import secret
import os
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext

MAX_MEMORY = "5g"
spark = SparkSession.builder.appName("today_dating") \
    .config("spark.executor.memory", MAX_MEMORY) \
    .config("spark.driver.memory", MAX_MEMORY) \
    .getOrCreate()

s3r = boto3.resource("s3", aws_access_key_id=secret.aws_access_id, aws_secret_access_key=secret.aws_access_secret)
bucket = s3r.Bucket("today-dating")

path = "date-blog/test.json"
file = bucket.Object(path).get()

data = file["Body"].read()

# df = spark.read.json(data)
# df.show()

# %%
import json

json.loads(data)
# Out:
# {'blog': [{'title': '답십리 해장국 맛집 장성식당과 <b>용답</b>카페 부루커피',
#    'link': 'https://blog.naver.com/clf123?Redirect=Log&logNo=222525733111',
#    'description': '그리고 용답역 바로 앞에 있는 청계천 앞에 벤치에서 천변 즐기며 부루커피 진짜 맛나게 먹었어요 !! 딱 답십리 데이트코스 - <b>용답데이트</b>코스로 좋은듯합니다! 서울여행와서 묵은 청량리호텔인 더 디자이너스... ',
#    'bloggername': '내 속엔 내가 너무도 많아',
#    'bloggerlink': 'https://blog.naver.com/clf123',
#    'postdate': '20211004'},
#   {'title': '서울, 매화 여행은 <b>용답</b>역 청계천 매화거리로',
#    'link': 'https://blog.naver.com/yo_onji?Redirect=Log&logNo=222686137521',
#    'description': '걷다보면 보이는 홍매화 ♥️ 대나무와 함께 피어있는데 색이 참 예뻤어요 ! 대나무도 푸릇푸릇 넘 예뻤구용 쉴수 있게 벤치도 있었어용! <b>데이트</b>나 산책으로 <b>용답</b>역 매화거리, 청계천 매화거리 추천드려요',
#    'bloggername': 'MY world',
#    'bloggerlink': 'https://blog.naver.com/yo_onji',
#    'postdate': '20220329'},
#   {'title': '서울 매화 명소 : <b>용답</b>역 청계천 하동매실거리 (ft. 개화 정도... ',
#    'link': 'https://blog.naver.com/bluesspace?Redirect=Log&logNo=222678216282',
#    'description': '서울 매화 명소: <b>용답</b>역 청계천 하동매실거리 (ft. 개화 정도, 위치) 안녕하세요! 얼마 전 뉴스에서... 대포 카메라를 든 분들도 사진 찍으러 많이 오셨고, <b>데이트</b>하는 분들도 서로 사진 찍어주고 계시고... ',
#    'bloggername': '매일 한걸음씩 꾸준히.',
#    'bloggerlink': 'https://blog.naver.com/bluesspace',
#    'postdate': '20220321'},
#   {'title': '서울 매화꽃 <b>용답</b>역 하동매실거리 서울 봄꽃 봄나들이 가볼만한곳',
#    'link': 'https://blog.naver.com/june_be?Redirect=Log&logNo=222686132451',
#    'description': '그래도 꼭 한 번은 가보고 싶어서 지난 3/26일 다녀온 <b>용답</b>역 하동매실거리 아마 지금쯤은 더 만개했을... 2호선 <b>용답</b>역에서 바로 연결되어 있다. <b>용답</b>역 2번출구 이용. 역 밖으로 나가서 <b>용답</b>역에서 신답역까지... ',
#    'bloggername': '오늘도 밝음♡',
#    'bloggerlink': 'https://blog.naver.com/june_be',
#    'postdate': '20220329'},
#   {'title': '<b>데이트</b>ㅣ한남동에서 따릉이타고 <b>용답</b>역까지',
#    'link': 'https://blog.naver.com/dmsgml094?Redirect=Log&logNo=222412047814',
#    'description': '#테이블링 앱 너무 편하다 다 먹구 한남역 쪽으로 올라가면 한강이 나오는데, 따릉이 빌려서 한강 라이딩 시작 댕댕이 하이 그림이 너무 귀여워서 원래 목표는 동네까지 가눈거였는데 2분의1 가구 포기:( <b>용답</b>역... ',
#    'bloggername': '평범한 일상 속 끄적끄적',
#    'bloggerlink': 'https://blog.naver.com/dmsgml094',
#    'postdate': '20210627'},
#   {'title': '<b>용답</b>깨비곱창은 <b>용답</b>역모임,<b>데이트</b>에 딱입니다.',
#    'link': 'https://blog.naver.com/wjddkssk62?Redirect=Log&logNo=221591325559',
#    'description': '#<b>용답</b>역곱창 #<b>용답</b>역모임 #<b>용답</b>역<b>데이트</b> #<b>용답</b>곱창 #<b>용답</b>곱창맛집 주소: 서울성동구 <b>용답</b>19길 5 예약번호:02-3394-6595 동생이랑 남편이랑 청계천<b>데이트</b>를 자주는데요~ 마장에서 <b>용답</b>역으로 가는 청계천길이 너무... ',
#    'bloggername': '아따맘띠의 wedding story ♡',
#    'bloggerlink': 'https://blog.naver.com/wjddkssk62',
#    'postdate': '20190721'},
#   {'title': '<b>용답</b>역맛집 모듬 1인분 10,000원 서울 최고의 가성비 소곱창... ',
#    'link': 'https://blog.naver.com/rony_02?Redirect=Log&logNo=222699486873',
#    'description': '여기는 술이 술+술+술 들어가는곳ㅋㅋ <b>용답</b>역 근처에서 술 약속 있으신 분들, 모임이나 <b>데이트</b>하시는 분들 추천드릴게요 #왕십리곱창 #왕십리소곱창 #소곱창 #곱창맛집 #곱창막창 #곱창대창막창 #수입소곱창... ',
#    'bloggername': 'rony_planet',
#    'bloggerlink': 'https://blog.naver.com/rony_02',
#    'postdate': '20220413'},
#   {'title': '하동 매실거리와 도깨비 촬영지인 <b>용답</b>역에 가보다',
#    'link': 'https://blog.naver.com/merry_jung?Redirect=Log&logNo=222292697952',
#    'description': '서울 <b>데이트</b>를 즐기기 좋은 코스입니다. 연인 둘이서 손잡고 걸어도 좋고 사진 가볍게 남기기 괜찮은 곳! 2호선 성수역에서 내려 갈아타서 <b>용답</b>에서 내렸습니다. 대략적으로 위치가 한양대학교 캠퍼스 뒤... ',
#    'bloggername': '혜윰 트래블 모먼트❤️',
#    'bloggerlink': 'https://blog.naver.com/merry_jung',
#    'postdate': '20210330'},
#   {'title': '청계천 매화거리(하동매실거리)  <b>용답</b>역 매화 곱게 피네요... ',
#    'link': 'https://blog.naver.com/hari33?Redirect=Log&logNo=222682087928',
#    'description': '#청계천매화거리 #하동매실거리 #<b>용답</b>역매화 #서울꽃구경 #매화와새 회사 일정이 좀 일찍 끝나서 <b>용답</b>역 매화 보러 청계천매화거리 다녀왔어요~^^* 막내와 <b>용답</b>역에서 만나 즐거운 서울꽃구경 <b>데이트</b>해서 좋던... ',
#    'bloggername': '엄마의 꿈&여행 - story 2',
#    'bloggerlink': 'https://blog.naver.com/hari33',
#    'postdate': '20220324'},
#   {'title': "서울<b>데이트</b> <b>용답</b>역 드라마 '도깨비' 촬영지",
#    'link': 'https://blog.naver.com/season1810?Redirect=Log&logNo=221194998574',
#    'description': '여기도 <b>용답</b>역 육교예요ㅎㅎㅎㅎ 드라마 촬영지로도 유명하지만 또한 <b>데이트</b> 장소로도 적정한 <b>용답</b>역 육교를 한 번 가보도록 할께요!! <b>용답</b>역은 성수역에서 신설동 사이를 운행하는 2호선을 타야갈 수가 있어요... ',
#    'bloggername': '캐시의일기장',
#    'bloggerlink': 'https://blog.naver.com/season1810',
#    'postdate': '20180127'},
#   {'title': '주말 <b>데이트</b> <b>용답</b>역 하동매실거리 / 성수동 카페, 에롤파',
#    'link': 'https://blog.naver.com/byul7708?Redirect=Log&logNo=221490584207',
#    'description': '촬영도 좋은데로 데려다준 우리 오빠에게 감사를❤️ #주말#<b>데이트</b>#성수동<b>데이트</b>#여자친구선물추천#카페 #나들이#성수카페#<b>용답</b>역#꽃놀이#매화#3월꽃놀이',
#    'bloggername': 'Juma,rae nade',
#    'bloggerlink': 'https://blog.naver.com/byul7708',
#    'postdate': '20190317'},
#   {'title': '벚꽃보러 청계천 하동 매실거리, <b>용답</b>역 벚꽃길 다녀왔어요!',
#    'link': 'https://blog.naver.com/storeu?Redirect=Log&logNo=222288461636',
#    'description': '<b>용답</b>역 <b>데이트</b> 하기 좋은 길 청계천 벚꽃 산책길 청계천 하동 매실거리 서울 벚꽃 개화 시기가 굉장히 빨라졌다. 예정일과 달리 벌써 벚꽃이 활짝 핀 곳도 있다! 곧 다가올 벚꽃 만개일을 대비해 미리 사전... ',
#    'bloggername': '주영의 일상',
#    'bloggerlink': 'https://blog.naver.com/storeu',
#    'postdate': '20210326'},
#   {'title': '[<b>용답</b>동 맛집] <b>용답</b> 로데오거리 쭈꾸미 전문점_미스터핑크... ',
#    'link': 'https://blog.naver.com/dustn9240?Redirect=Log&logNo=222583293862',
#    'description': '가성비맛집 #동네맛집 #미스터핑크 #쭈꾸미전문점 #쭈꾸미맛집 #맛집추천 #<b>용답</b>동로데오거리 #<b>용답</b>동로데오거리맛집 #로데오거리맛집추천 #답십리사거리맛집 #답사맛집 #<b>데이트</b> #소통 #서이추환영 #답방',
#    'bloggername': '뚜비뚜비 욘뚜비ღ',
#    'bloggerlink': 'https://blog.naver.com/dustn9240',
#    'postdate': '20211130'},
#   {'title': '사근동 이색 카페 앨리(<b>용답</b>역 커피)',
#    'link': 'https://blog.naver.com/jbcafe?Redirect=Log&logNo=222398181216',
#    'description': '고고~♡♡♡ 사근동 이색 카페 앨리(<b>용답</b>역 커피) 성동구에는 흔히 말하는 핫플레이스가 많고, 먹거리, 즐길거리도 풍부해서 남녀 <b>데이트</b>코스, 이색 여행 코스로 좋은 곳들이 많아서 많은 이들에게 사랑받는... ',
#    'bloggername': '고고위드 산낙지 | 맛•건강•여행',
#    'bloggerlink': 'https://blog.naver.com/jbcafe',
#    'postdate': '20210614'},
#   {'title': '왕십리 <b>용답</b>역 주변 청계천 <b>데이트</b>',
#    'link': 'https://blog.naver.com/dudnr456?Redirect=Log&logNo=221544299039',
#    'description': '운동하러 <b>용답</b>역쪽으로 갔어요. <b>용답</b>역 바로 앞에 청계천이 있어서 운동하기 좋아요! 빙구랑 걷기도... 빙구도 유로파 남색 있다고 해서 나중에 커플로 입고 다니기로 했어요,, #왕십리<b>데이트</b> #190517 #일상... ',
#    'bloggername': '욱이콩이',
#    'bloggerlink': 'https://blog.naver.com/dudnr456',
#    'postdate': '20190523'},
#   {'title': '[서울 <b>데이트</b>/서울 맛집/답십리 맛집/답십리 횟집] <b>용답</b> 시장... ',
#    'link': 'https://blog.naver.com/iyemwo?Redirect=Log&logNo=221940011617',
#    'description': '* 본 포스팅은 광고가 아닌, 저자의 주관적인 솔직 리뷰입니다. * 안녕하세요. 내 돈 주고 내가 먹는 이예뭐입니다. 오늘 포스팅은 바로 숭어입니다! 일단 사진 한번 보고 가시쥬! 이곳은 바로바로!! 선굼터... ',
#    'bloggername': 'IYEMWO',
#    'bloggerlink': 'https://blog.naver.com/iyemwo',
#    'postdate': '20200501'},
#   {'title': '<b>용답</b>역 맛집 노포 소문난순대국왕족발 가성비 최고',
#    'link': 'https://blog.naver.com/sslove0826?Redirect=Log&logNo=221876118249',
#    'description': '<b>용답</b>역 맛집 근처 소문난순대국왕족발 40년동안 가게를 이어온 전통맛집인데요. 포장도 자주해가지만 안에서 순대국이랑 족발 같이 먹으면 정말맛있거든요. 간만에 여자친구랑 <b>데이트</b>왔다가 생각나서 족발이랑... ',
#    'bloggername': '봉구님의블로그',
#    'bloggerlink': 'https://blog.naver.com/sslove0826',
#    'postdate': '20200327'},
#   {'title': '<b>용답</b>역 투어::',
#    'link': 'https://blog.naver.com/wir800?Redirect=Log&logNo=221972385894',
#    'description': '<b>용답</b>역 투어 생각보다 괜찮았어요! 사진찍는 거 좋아하시는 분들은 #스튜디오페어 에서 사진찍은 후에 근처로 <b>데이트</b>를 가도 좋을 것 같아요. 하늘쌤은 이만 뿅. instagram @ju_sky ⓒ2020. 저하늘 all right reserved',
#    'bloggername': 'JᴜSᴋʏ BʟOɢ ✧･ﾟ: *',
#    'bloggerlink': 'https://blog.naver.com/wir800',
#    'postdate': '20200522'},
#   {'title': '서울에서 만나는 매화 | <b>용답</b>역 하동 매실거리 산책코스 봄꽃... ',
#    'link': 'https://blog.naver.com/2ufrom2?Redirect=Log&logNo=222284155121',
#    'description': '얼마 전 열심히 스냅 촬영으로, <b>데이트</b>로 다녀온 청계천 하동 매실거리. 이미 사진 찍는 사람들 뿐... 현재 바로 나올 수 있도록 연결되어 있다.) 2호선 내선순환 <b>용답</b>역 2번 출구에 있는 청계천변으로 나와 몇... ',
#    'bloggername': "22's YESTERDAY",
#    'bloggerlink': 'https://blog.naver.com/2ufrom2',
#    'postdate': '20210322'},
#   {'title': '산책/청계천 <b>데이트</b> 추천 코스]다산교&gt;청혼의 벽&gt;사근동&gt;<b>용답</b>... ',
#    'link': 'https://blog.naver.com/kkh6727?Redirect=Log&logNo=222462097536',
#    'description': '성동구 사근동 좋다 #휴대폰무료충전소도 있구여~ 자전거 도로도 잘되어 있네여 자전거 정말 씽씽 달려서 조굼 무서워뜸 씽씽 달리는 자전거들에 쫄며 걷다보니 어느덧 #<b>용답</b>동 부지런히 걷자~ #한양대학교 후문... ',
#    'bloggername': '레인보우썸머님의 블로그',
#    'bloggerlink': 'https://blog.naver.com/kkh6727',
#    'postdate': '20210808'},
#   {'title': '[별이랑영이랑_별이버전] 서울 매화포인트 : <b>용답</b>역 하동 매화거리',
#    'link': 'https://blog.naver.com/totquf1404?Redirect=Log&logNo=221884089073',
#    'description': '별이랑영이랑스냅 #<b>용답</b>역스냅 #스냅사진 #스냅촬영장소 #서울사진찍기좋은장소 #서울사진스팟 #서울핫플 #서울숲 #서이추 #서이추환영 #캐논 #소니 #색감 #스냅작가 #수원스냅 #수원<b>데이트</b>스냅 #수원개인스냅... ',
#    'bloggername': "'별이랑영이랑'스냅",
#    'bloggerlink': 'https://blog.naver.com/totquf1404',
#    'postdate': '20200401'},
#   {'title': '[<b>용답</b>동<b>데이트</b>]<b>용답</b>맛집,답십리샌드위치배달,사이사이샌드위치... ',
#    'link': 'https://blog.naver.com/phm7859?Redirect=Log&logNo=221744957875',
#    'description': '주말을 맞아 남친이랑 <b>데이트</b>하구 왔어용 &gt;&lt; 주로 동네<b>데이트</b>를 좋아하는지라 지난번 갔었던... ㅋㅋㅋㅋ 사장님이 드시던 커피가있는데 하트도 귀여워서 사진한번찍으면 안되냐고 부탁했어요 ㅋㅋㅋ <b>용답</b>동... ',
#    'bloggername': '서울무료꽃배달 꿈꾸는 옥상정원',
#    'bloggerlink': 'https://blog.naver.com/phm7859',
#    'postdate': '20191221'},
#   {'title': '<b>용답</b>역 청개천  벗꽃길 산책했어요',
#    'link': 'https://blog.naver.com/hblifelove?Redirect=Log&logNo=222291079162',
#    'description': "연인이 <b>데이트</b> 나왔나봐요 꽃앞에서 포즈를 잡고 예쁜사진을 '찰칵' 좋아보이네요~ 2호선 <b>용답</b>역을 가로질러 로데오거리도 갔어요 그냥 시장같은 느낌이었어요 드라마 촬영지였음을 알리고 있네요 매화는... ",
#    'bloggername': '엘사의 일상 이야기',
#    'bloggerlink': 'https://blog.naver.com/hblifelove',
#    'postdate': '20210329'},
#   {'title': '김치찌개/답십리역맛집/서울맛집/성동구맛집/<b>용답</b>로데오맛집',
#    'link': 'https://blog.naver.com/lxhxjx1203?Redirect=Log&logNo=222352382688',
#    'description': '통돼지 두루치기&amp;김치찌개 서울특별시 성동구 <b>용답</b>중앙15길 5-1 ( 성동구 <b>용답</b>동 57-5 ) #답십리역... 원래 저희가 #첫<b>데이트</b> 때 이곳을 방문했었는데, 그때는 블로그 운영을 안하고 있어서 포스팅을 못했는데... ',
#    'bloggername': '걸어서, 속으로',
#    'bloggerlink': 'https://blog.naver.com/lxhxjx1203',
#    'postdate': '20210515'},
#   {'title': '[청계천 하동 매실거리] <b>용답</b>역 벚꽃보러 하동 매실거리... ',
#    'link': 'https://blog.naver.com/storeu?Redirect=Log&logNo=222294483956',
#    'description': '<b>용답</b>역 2번출구 하동 매실거리 내맘대로 정한 하동 매실거리 입구 :) 매화와 벚꽃보길 기대 중 양 옆으로 꽃들이 활짝펴있으니 제대로 봄느낌이 난다. <b>데이트</b>하기 딱 좋은 길! 청계천 곳곳에는 이렇게 위치를... ',
#    'bloggername': '주영의 일상',
#    'bloggerlink': 'https://blog.naver.com/storeu',
#    'postdate': '20210401'},
#   {'title': '<b>용답</b>역 매화거리 부담없이 즐기는 봄날',
#    'link': 'https://blog.naver.com/sawtiger?Redirect=Log&logNo=221873646319',
#    'description': '오늘은 서울 <b>용답</b>역에 위치한 하동매실거리, 흔히 매화거리라 불리는 곳을 소개하려 한다. 사실 평생 서울에 살아왔지만 <b>용답</b>역이 있다는 건 이번 기회에 처음 알게 되었다. 그만큼 알려지지 않은 곳이라는... ',
#    'bloggername': 'B급 정서의 스트리트 포토그래퍼 서타이거 만만세 !!!',
#    'bloggerlink': 'https://blog.naver.com/sawtiger',
#    'postdate': '20200326'},
#   {'title': '인생 고깃집 잡부구이 잡숴봐요❤️ <b>용답</b>역맛집 답십리맛집... ',
#    'link': 'https://blog.naver.com/zwowz1004?Redirect=Log&logNo=221903296879',
#    'description': 'ㅎㅎㅎㅎ 빨리 코로나가 끝나길 바라며 !! 모두들 좋은 주말 되세요 :) #서울맛집 #로데오거리맛집 #광명마포잡부구이 #마포잡부구이 #답십리역맛집 #<b>용답</b>역맛집 #고기맛집 #잡부구이 #<b>데이트</b>코스',
#    'bloggername': 'Gyum님의 블로그',
#    'bloggerlink': 'https://blog.naver.com/zwowz1004',
#    'postdate': '20200411'},
#   {'title': '<b>용답</b>역맛집, 진짜 간만에 다녀온 소문난보배곱창',
#    'link': 'https://blog.naver.com/rilymin123?Redirect=Log&logNo=222678470378',
#    'description': '이렇게 #서울<b>데이트</b> 갈 때에는 어차피 차 놓고 가니까 ㅋㅋㅋ 대중교통 이용해서 둘이 같이 수원으로 넘어오면 되니까 좋은 것 같아요 ㅋㅋㅋ 조만간 또 가고 싶은 <b>용답</b>역맛집 하지만 ㅠㅠ 요즘 난리라 당분간은... ',
#    'bloggername': '키매친♥낭만곰이 맛집,뷰티,일상이야기 ♬',
#    'bloggerlink': 'https://blog.naver.com/rilymin123',
#    'postdate': '20220321'},
#   {'title': '청계천 <b>용답</b>역 하동매실거리 매화 보고 왔다',
#    'link': 'https://blog.naver.com/mirove21?Redirect=Log&logNo=221496673314',
#    'description': '그래서 한번 걸어갔다가 다시 <b>용답</b>역까지 걸어서 돌아왔다. 서울에서 볼 수 있는 매화거리이지만 사람들이 엄청 많거나 그러진 않았다. 주민들처럼 보이는 분들이 많고 우리처럼 <b>데이트</b> 나온 커플들, 그리고... ',
#    'bloggername': '마지막 chance',
#    'bloggerlink': 'https://blog.naver.com/mirove21',
#    'postdate': '20190325'},
#   {'title': '유니콘 프라페 - 메가커피 답십리로데오점 (<b>용답</b>역 메가커피... ',
#    'link': 'https://blog.naver.com/ksfe1116?Redirect=Log&logNo=222363169051',
#    'description': "오늘 먹어본 음료는 대세 프렌차이즈, 메가커피의 시그니처 메뉴 '유니콘 프라푸치노'에요 2호선 <b>용답</b>... 라는 생각이 들긴 했어요 기분 꾸리꾸리한 날, <b>데이트</b>, 예쁜 디저트 먹고 싶은 날, 인스타 사진 찍기... ",
#    'bloggername': '일상 먹방 리뷰',
#    'bloggerlink': 'https://blog.naver.com/ksfe1116',
#    'postdate': '20210523'},
#   {'title': '3기 김지효(2호선 성수지선,신답역,공원<b>데이트</b>,<b>용답</b>근린공원)',
#    'link': 'https://blog.naver.com/seoulmetro01?Redirect=Log&logNo=120164255285',
#    'description': '서울메트로의 시크릿가든 신답역을 김지효 해피메신저가 소개합니다. 출처 : 김지효 서울메트로 해피메신저 블로그 http://www.cyworld.com/dihyo71',
#    'bloggername': '서울교통공사 블로그',
#    'bloggerlink': 'https://blog.naver.com/seoulmetro01',
#    'postdate': '20120718'},
#   {'title': '답십리 한우갈비, <b>용답</b> 한우갈비짝',
#    'link': 'https://blog.naver.com/lala225?Redirect=Log&logNo=221738282743',
#    'description': '가족.<b>데이트</b>에 안성맞춤 답십리 한우갈비, <b>용답</b> 한우갈비짝 1등급 한우갈비만 취급한답니다 직접 주방에서 바로 썰여주는게 특징이에요 주문하면 기본적으로 나오는 메뉴에요 답십리 한우갈비, <b>용답</b>... ',
#    'bloggername': 'modern life',
#    'bloggerlink': 'https://blog.naver.com/lala225',
#    'postdate': '20191215'},
#   {'title': '서울 도깨비촬영지 : <b>용답</b>역 도깨비 육교',
#    'link': 'https://blog.naver.com/jjung00405?Redirect=Log&logNo=221313398229',
#    'description': '공원으로 조성되어 있어서 운동기구들도 많고 자전거 도로도 잘 되어있어서 자전거타고 나오시는 분들도 많더라구요 서울 도깨비촬영지 <b>용답</b>역 도깨비육교에서 <b>데이트</b>하고 <b>용답</b>동 맛집 순회 한번 하고가세용~~~',
#    'bloggername': '김끌림마켓❤',
#    'bloggerlink': 'https://blog.naver.com/jjung00405',
#    'postdate': '20180705'},
#   {'title': '데이트,답십리단체간식,용답사... 옥수수와플,<b>용답데이트</b>',
#    'link': 'https://blog.naver.com/phm7859?Redirect=Log&logNo=221718104726',
#    'description': '엄청나게 오랜만에 쓰는 포스팅이에요 &gt;&lt; 제가 사는 동네, <b>용답</b>동에 샌드위치전문점이 생겼어요 ^^ 개인매장인데 너무 이쁘고 여자들은 다 좋아하는 샌드위치라니 ㅠㅠ 와플이랑 토스트도 있어서 아이들... ',
#    'bloggername': '서울무료꽃배달 꿈꾸는 옥상정원',
#    'bloggerlink': 'https://blog.naver.com/phm7859',
#    'postdate': '20191125'},
#   {'title': '(하동 매실거리), 길상사, 봄꽃 여행 축제 <b>데이트</b> 갈만한곳 추천',
#    'link': 'https://blog.naver.com/suntill0210?Redirect=Log&logNo=222662364157',
#    'description': '2호선 <b>용답</b>역으로 가면 바로 만나볼 수 있어 접근성도 좋고 청계천을 따라 <b>데이트</b> 하기도 참 좋은 곳 입니다. 지금까지 서울에서도 매화꽃 보기 좋은 곳을 소개해 드렸는데요 이제 남쪽은 하나 둘... ',
#    'bloggername': 'DHK.Photogallery',
#    'bloggerlink': 'https://blog.naver.com/suntill0210',
#    'postdate': '20220302'},
#   {'title': '청계천 동물친구 찾기 서울 <b>데이트</b>코스 산책',
#    'link': 'https://blog.naver.com/neweunha?Redirect=Log&logNo=222592351583',
#    'description': '서울 <b>데이트</b>코스 산책하기 좋은 길로 <b>용답</b>역과 신답역 사이 청계천을 추천합니다. 지하철역 출구와 바로 이어져 접근성이 좋은데다가 한적한 자연을 느껴볼 수 있는 서울 산책 코스 입니다. 청계천의 총 길이... ',
#    'bloggername': '여행작가 박은하',
#    'bloggerlink': 'https://blog.naver.com/neweunha',
#    'postdate': '20211210'},
#   {'title': '3월 일상 ! 따듯해 !',
#    'link': 'https://blog.naver.com/flysjy97?Redirect=Log&logNo=222690731360',
#    'description': '3/9 (수) 오랜만에 아빠랑 자전거 <b>데이트</b>! <b>용답</b>에서 뚝섬유원지까지 신나게 달렸다! 땀 흘린 날은 역시 엽떡에 교촌이지! 3/10 (목) 엄마가 행사 사회봐달라해서 연차내고 여주 내려갔다. 여주시장 도의원... ',
#    'bloggername': '질서정연한 블로그',
#    'bloggerlink': 'https://blog.naver.com/flysjy97',
#    'postdate': '20220403'},
#   {'title': '청계천 매화 (서울에서 매화꽃보기 좋은 곳 <b>용답</b>역에서) 산책... ',
#    'link': 'https://blog.naver.com/hari33?Redirect=Log&logNo=220961887085',
#    'description': '<b>용답</b>역에서 신답역 사이 길이구요. 들려보셔도 좋을 곳 같아요. 가까이 사는데 처음 걸어봐서.. 저에게 또 구박을..ㅋㅋ 저 뒷 건물이 신답역이예요. <b>데이트</b>코스 추천해달라면 음.. 신답역에서 좀 더 걸으면... ',
#    'bloggername': '엄마의 꿈&여행 - story 2',
#    'bloggerlink': 'https://blog.naver.com/hari33',
#    'postdate': '20170319'},
#   {'title': '<b>용답</b>역 뚝방길 | 서울 매화 웨딩촬영, 삼각대 셀프웨딩',
#    'link': 'https://blog.naver.com/hanyeonji92?Redirect=Log&logNo=221628609355',
#    'description': '결혼, #결혼 #셀프웨딩 #웨딩사진 #<b>데이트</b>스냅 #삼각대웨딩 #셀프촬영 이번에 우리가 찾아간 장소는 #<b>용답</b> #뚝방길매화 매화는 봄을 알리는 꽃으로 , 올해는 #매화 봄을 알리는 꽃 매화, 올해는 좋아하는 팡도르... ',
#    'bloggername': '순간을 기억해요,',
#    'bloggerlink': 'https://blog.naver.com/hanyeonji92',
#    'postdate': '20190826'},
#   {'title': '<b>용답</b>동 맛집 : 자극적이지 않아서 더 맛있는 돼지곱창 <b>용답</b>깨비... ',
#    'link': 'https://blog.naver.com/b_bsong?Redirect=Log&logNo=221932314490',
#    'description': '안녕하세요 오늘은 예전에 송보릿이 다니던 학교 근처에 <b>데이트</b>를 갔다가 맛있는 집이 있어서 먹고 왔답니다! ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 요기는 위치가 아주 그레잇 해요! <b>용답</b>역 1번출구에서 걸어서... ',
#    'bloggername': '페이보릿 송,',
#    'bloggerlink': 'https://blog.naver.com/b_bsong',
#    'postdate': '20200429'},
#   {'title': '서울 가볼만한곳 청계천 매화거리 하동매실거리 주말 <b>데이트</b>코스',
#    'link': 'https://blog.naver.com/mixsun?Redirect=Log&logNo=222278359720',
#    'description': '주말<b>데이트</b>코스로 추천하고 싶은 이유는 제가 다녀와보니 이번주 주말까지는 싱싱한 꽃을 만날수 있을것 같기 때문이에요. 꽃 사진 찍으실 분들 허리업! 1. <b>용답</b>역 청계천 매화거리 / 하동매실거리 4년정도를... ',
#    'bloggername': '사진 속 일상에서 여행을 하다',
#    'bloggerlink': 'https://blog.naver.com/mixsun',
#    'postdate': '20210317'},
#   {'title': '<b>용답</b>역맛집 사랑해물 답십리 해물찜 짱맛',
#    'link': 'https://blog.naver.com/tladydgustn?Redirect=Log&logNo=220507227192',
#    'description': '주말에 엄마랑 <b>데이트</b>를 해쬬~ 맛나눙 해물찜을 먹기 위해서 다녀온곳은 바로바로 <b>용답</b>역맛집 사랑해물! 저희는 여기를 자주 가곤해요 맛도 맛있지만 양념이 맵구 자꾸만 땡겨서 자주 가곤하죠. 저희가 찾은... ',
#    'bloggername': '수퍼맨파워',
#    'bloggerlink': 'https://blog.naver.com/tladydgustn',
#    'postdate': '20151013'},
#   {'title': "<b>용답</b>역 맛집/ <b>용답</b>역 소곱창맛집 : 적극 추천하는 '승수네... ",
#    'link': 'https://blog.naver.com/parkz8194?Redirect=Log&logNo=221567376819',
#    'description': "<b>용답</b>역 맛집/ <b>용답</b>역 소곱창맛집 적극 추천하는 '승수네 왕십리 곱창' 지난번에 다녀온 <b>용답</b>역 '승수네... 곱창 <b>데이트</b> 삼겹살 100번 먹을 때 곱창 두 번 먹네.. 한 편으로는 다행이야.. 오빠가 곱창을 안... ",
#    'bloggername': 'Episode 2',
#    'bloggerlink': 'https://blog.naver.com/parkz8194',
#    'postdate': '20190621'},
#   {'title': '<b>용답</b>맛집 <b>용답</b>깨비곱창 , 곱창만큼 맛있었던 인생 오돌뼈 등장',
#    'link': 'https://blog.naver.com/eso0609?Redirect=Log&logNo=221446256645',
#    'description': '<b>용답</b>맛집 <b>용답</b>깨비곱창 볶음밥 볶음밥은 무조건 먹어줘야 합니다 ㅎㅎ 볶음밥을 먹으면서 후임이 갑자기 여자친구분이랑 오실 때 <b>데이트</b>코스를 알려주겠대요. 그래서 들어봤는데..ㅎㅎ 왕십리 아이맥스가... ',
#    'bloggername': '엄코딩의하루',
#    'bloggerlink': 'https://blog.naver.com/eso0609',
#    'postdate': '20190120'},
#   {'title': '답십리 동전노래방, <b>용답</b> 쉐프포차',
#    'link': 'https://blog.naver.com/sodamingg?Redirect=Log&logNo=220779182394',
#    'description': '가깝고 <b>용답</b>역에서도 가까운 이름이 엣지 동전노래방인데 사실..마이크가 좋은편이 아니다.... ㅋㅋ 밤되서 쉐프포차로 감 ~~~ 동네 앞이니까 부담도 안되서 자주 가는 곳인데 이 날은 더블<b>데이트</b>였지..! 헤헤... ',
#    'bloggername': '소담메이크업MUA',
#    'bloggerlink': 'https://blog.naver.com/sodamingg',
#    'postdate': '20160804'},
#   {'title': '<b>용답</b>역맛집 도네누 볏짚 통삼겹에서 회식',
#    'link': 'https://blog.naver.com/prince_kdk?Redirect=Log&logNo=221356796059',
#    'description': '생각하는) <b>용답</b>역맛집 도네누 볏짚 통삼겹에 다녀왔습니다 ^^ 이곳은 예전에 다른 직원이랑도 와본... 위치는 답십리역 사거리에서 <b>용답</b>역방향으로 가는 길에 있는 로데오거리에 위치해 있는데요. 자세한 위치는... ',
#    'bloggername': '꼴뚜기왕자의 지구 탐방 이야기!!',
#    'bloggerlink': 'https://blog.naver.com/prince_kdk',
#    'postdate': '20180911'},
#   {'title': '회사 근처 <b>용답</b>역뚝방길!!~',
#    'link': 'https://blog.naver.com/seminwoo3894?Redirect=Log&logNo=220676113287',
#    'description': '<b>용답</b>역뚝방길이라고 하는데 2번출구에 있어요~ 이곳에 사는 사람들은 좋겠어요. 저희 동네는 온통... 커플<b>데이트</b> 코스로 좋지 않을까 생각되고 오늘같은 날에는 밤에 나오면 시원하고 돗자리깔고 맥주한캔... ',
#    'bloggername': '★드림헤어라인의원★',
#    'bloggerlink': 'https://blog.naver.com/seminwoo3894',
#    'postdate': '20160406'},
#   {'title': '<b>용답</b>역에 위치한 분위기 좋은 청계천 인도교',
#    'link': 'https://blog.naver.com/poi43211?Redirect=Log&logNo=220603386401',
#    'description': '특히 제가 자주가는 <b>용답</b>역근처 코스는 갈대코스가 있어서 분위기도 좋아요~ 내가 늬엇늬엇지는 시간이면 해가 반사되어 반짝반짝 너무 예쁘더라구요. <b>데이트</b> 코스로도 강추! 저처럼..사색즐기기도 너무 좋아요!... ',
#    'bloggername': '공실마 부동산마케팅',
#    'bloggerlink': 'https://blog.naver.com/poi43211',
#    'postdate': '20160120'},
#   {'title': "<b>용답</b> 맛집 ....이름을 멀랑 '-'",
#    'link': 'https://blog.naver.com/x_yhs?Redirect=Log&logNo=90175363427',
#    'description': '바쁨 <b>데이트</b>해야함 헤헤 ㅎㅎㅎㅎ 암튼 메밀전!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! 묵밥!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!... 아무도 <b>용답</b>까지 와서 이거 먹을 생각 안 하잖아 식당이름 몰라도 괜찮잖아????????????????? <b>용답</b>이... ',
#    'bloggername': '낮잠nap',
#    'bloggerlink': 'https://blog.naver.com/x_yhs',
#    'postdate': '20130618'},
#   {'title': "서울 <b>용답</b>동 <b>용답</b>역 '하동매실거리, 담양대나무숲' :: 서울에 핀... ",
#    'link': 'https://blog.naver.com/juanxi?Redirect=Log&logNo=221906801572',
#    'description': '아니라 <b>용답</b>동이네 서울의 하동매실거리 대중교통을 타고 간다면 지하철 2호선 <b>용답</b>역 2번 출구가 가깝겠다 근처 버스 정류장 이름은 사근동 하이츠 아파트 앞 그래서 사근동인 줄 알았는데 이제 보니... ',
#    'bloggername': "Juanxi's travel & food ::",
#    'bloggerlink': 'https://blog.naver.com/juanxi',
#    'postdate': '20200413'},
#   {'title': '청계천 산책 낮과 밤♥물소리와 꽃길(서울<b>데이트</b>추천... ',
#    'link': 'https://blog.naver.com/hari33?Redirect=Log&logNo=222403031536',
#    'description': '청계천의 밤의 시원해서 서울<b>데이트</b>추천하며 현재 <b>용답</b>역에서 용두역은 꽃길이라 서울산책하기좋은곳으로 함께 소개해볼께요~♥ https://m.blog.naver.com/hari33/222401455575 따릉이타고 청계천 상류부터 하류까지... ',
#    'bloggername': '엄마의 꿈&여행 - story 2',
#    'bloggerlink': 'https://blog.naver.com/hari33',
#    'postdate': '20210619'},
#   {'title': '서울 성동구 <b>용답</b>동 하동매실거리 (22.03.22)',
#    'link': 'https://blog.naver.com/yunhj427?Redirect=Log&logNo=222680484196',
#    'description': '봄은 짧으니 (마스크 잘 쓰고) 어서 밖으로 나오시라. #하동매실거리 #청계천매화거리 #서울봄꽃 #서울봄꽃명소 #서울매화 #서울매화명소 #<b>용답</b>역매화 #서울가볼만한곳 #서울<b>데이트</b> #서울봄<b>데이트</b>',
#    'bloggername': '잘 먹고 잘 뛰어봅시다',
#    'bloggerlink': 'https://blog.naver.com/yunhj427',
#    'postdate': '20220323'},
#   {'title': '서울 가볼만한곳 - 울집 댕댕이와 청계천 산책',
#    'link': 'https://blog.naver.com/younoky2?Redirect=Log&logNo=222699150797',
#    'description': '고물고물 하네요~ 사람들이 내려다보니 몰려와서~ <b>용답</b>역 앞에서 잠시 쉬멍~ 항시 더 멀리 갔었는데 오늘은 오래간만에 간고로 너무 힘들까 봐 <b>용답</b>역 다리에서 턴했어요. 한나도 지난해 많이 아팠지만 울 집... ',
#    'bloggername': '한나의 행복',
#    'bloggerlink': 'https://blog.naver.com/younoky2',
#    'postdate': '20220413'},
#   {'title': '3월 가볼만한곳 베스트 3 그리고 <b>데이트</b> 필수아이템 오카모토... ',
#    'link': 'https://blog.naver.com/toyporno?Redirect=Log&logNo=222666375766',
#    'description': '하동매실거리 청계천 매화거리라고도 불리는 하동매실거리는 <b>용답</b>역과 신답역 사이 청계천에 조성된 꽃길입니다. 이곳은 3월 <b>데이트</b> 장소를 찾는 커플이라면 꼭 한번 가봐야 하는 곳입니다. 물길을 따라... ',
#    'bloggername': '토이포르',
#    'bloggerlink': 'https://blog.naver.com/toyporno',
#    'postdate': '20220309'},
#   {'title': '가을<b>데이트</b>는 성동 축제와 함께!',
#    'link': 'https://blog.naver.com/seongdonggu1?Redirect=Log&logNo=221680497486',
#    'description': '키즈존, 먹거리장터 등 ★ <b>용답</b>동 주민센터(2286-7545) 깊어가는 가을! 축제는 성동과 함께! 놀러오세요~~~ #서울숲 #<b>데이트</b>코스 #가을축제 #가을행사 #지역행사 #서울_가볼만한곳 #행사장 #무료체험',
#    'bloggername': '성동구청 블로그',
#    'bloggerlink': 'https://blog.naver.com/seongdonggu1',
#    'postdate': '20191017'},
#   {'title': '3월 셋째주 강미네의 일상',
#    'link': 'https://blog.naver.com/minhye526?Redirect=Log&logNo=222678029558',
#    'description': '포은이와 <b>용답</b>이 햇볕쐬어주기 ~ ~ 식물 초보지만 열심히 키우려고 노력하는 엄마 마음 잘 알아줘라... 헤헤 금남방 오랜만에 갔더니 <b>데이트</b>하는 기분 물씬 휴 킹크랩 한라봉 냉채 이거 넘 맛있어서 기절. 확실히... ',
#    'bloggername': '강미네의 블로그',
#    'bloggerlink': 'https://blog.naver.com/minhye526',
#    'postdate': '20220321'},
#   {'title': '3월 서울 가볼만한곳, 뚜벅이도 싱그럽게 놀러가자',
#    'link': 'https://blog.naver.com/seouldatepop?Redirect=Log&logNo=222666167583',
#    'description': '[<b>용답</b>역] 하동매실거리 서울에 웬 하동거리?! 청계천 매화거리라고도 불리는 하동매실거리는 <b>용답</b>역과... 이날은 오랜만에 모모네 댕댕이 솜이도 같이 <b>데이트</b>했어요. 물길을 따라 산책로도 아주 깔끔하게... ',
#    'bloggername': '데이트팝',
#    'bloggerlink': 'https://blog.naver.com/seouldatepop',
#    'postdate': '20220307'},
#   {'title': '[<b>용답</b>카페]카페와 로또(caffe&amp;lotto)',
#    'link': 'https://blog.naver.com/wlalsrhkals?Redirect=Log&logNo=221394995771',
#    'description': '[<b>용답</b>카페][<b>용답</b>로또] 친구들과 커피마시며 재미로 즉석복권 긁으며 시간 보내기 좋은곳이었어요. 이색 <b>데이트</b>로 방문해 보는것도 좋을것 같아요! 당첨자분들이 꽤 나왔다고 하니 여러분들도 행운의 주인공이... ',
#    'bloggername': '민로그',
#    'bloggerlink': 'https://blog.naver.com/wlalsrhkals',
#    'postdate': '20181109'},
#   {'title': '[<b>용답</b> 맛집] 착한가격 착한맛집 도네누 볏짚삼겹살',
#    'link': 'https://blog.naver.com/saemeek?Redirect=Log&logNo=220294668295',
#    'description': '저는 주말이면 어김없이 남자친구를 만나 <b>데이트</b>를 하는데요~지난 일요일에 남자친구와 <b>데이트</b>하면서 찾아간 고기맛집을 포스팅 할거에요 오늘 소개해드릴 맛집은 저희 커플이 정말 격하게 사랑하는 <b>용답</b>의... ',
#    'bloggername': '김쌤의 일상',
#    'bloggerlink': 'https://blog.naver.com/saemeek',
#    'postdate': '20150309'},
#   {'title': '<b>용답</b>역·답십리역 한성아펠시티 상가&amp;오피스텔 투룸, 분리형... ',
#    'link': 'https://blog.naver.com/sampleroom?Redirect=Log&logNo=221094658715',
#    'description': '여긴 <b>데이트</b>장소루다가~ㅎㅎ 동대문구 아파트 재건축, 재개발 현황 뉴타운의 미래가치에 풍부한 임대수요 답십리·<b>용답</b>역 더블역세권에 청계천의 쾌적함 [2030 서울시 생활권 계획] 동북·서남·서북권... ',
#    'bloggername': '으랏차차 18OO-9178',
#    'bloggerlink': 'https://blog.naver.com/sampleroom',
#    'postdate': '20170911'},
#   {'title': '서울 꽃 구경 갈 때가 됐어! 서울 피크닉도 준비 완료!',
#    'link': 'https://blog.naver.com/seouldatepop?Redirect=Log&logNo=222676449368',
#    'description': '처음이 아닌 한복 <b>데이트</b>지만 이번에는 모모가 직접 한복을 골라줘서 괜히 더 두근거리는 기분ㅎㅎ... [<b>용답</b>역] 하동매실거리 군침이 싹~ 도는 매화거리 <b>용답</b>역에서 신답역 사이 청계천변에 위치한... ',
#    'bloggername': '데이트팝',
#    'bloggerlink': 'https://blog.naver.com/seouldatepop',
#    'postdate': '20220319'},
#   {'title': '청계천 <b>데이트</b> 및 매화거리 가는방법',
#    'link': 'https://blog.naver.com/chansxor1?Redirect=Log&logNo=220657780539',
#    'description': '청계천 <b>데이트</b> 및 매화거리 가는방법 이웃님들 청계천 하면 제일 먼저 생각나는게 청계광장이지요... 2호선 <b>용답</b>역과 신답역 사이에 있답니다 2호선 신답역이나 5호선 마장역 2번 출구에서 청계천 생태교실 옆... ',
#    'bloggername': '별빛사랑의 여행스케치',
#    'bloggerlink': 'https://blog.naver.com/chansxor1',
#    'postdate': '20160317'},
#   {'title': '올가을 꼭 다녀와야 할 인생 사진 스폿은 어디? 서울 단풍명소... ',
#    'link': 'https://blog.naver.com/haechiseoul?Redirect=Log&logNo=222559401144',
#    'description': '<b>데이트</b> 코스로 딱 좋은 메타세쿼이아길 하늘공원 계단에서 난지순환길 방향으로 이동하면 부드러운... 보면 <b>용답</b>역 다리를 마주하게 되는데요. 잠깐, 뭔가 신비로운 것이 보이지 않나요? 이곳은 바로 김은숙... ',
#    'bloggername': '서울특별시 공식블로그',
#    'bloggerlink': 'https://blog.naver.com/haechiseoul',
#    'postdate': '20211105'},
#   {'title': '<b>데이트</b> - 답십리 현대시장, 곱창 먹으러',
#    'link': 'https://blog.naver.com/jongeoni?Redirect=Log&logNo=221390052642',
#    'description': '<b>데이트</b> 겸 운동을 겸해서 멀리 답십리 현대 시장에 다녀왔습니다. 전에 지나갈 때 인상 깊게 봤던 터라... 돌아오는 길은 <b>용답</b> 시장에 들러서 왔습니다... 여기도 또 곱창 천국이더군요 ㅎㅎ',
#    'bloggername': '일상의 즐거움',
#    'bloggerlink': 'https://blog.naver.com/jongeoni',
#    'postdate': '20181102'},
#   {'title': '동묘시장 <b>데이트</b>',
#    'link': 'https://blog.naver.com/aussie_lee?Redirect=Log&logNo=221034884181',
#    'description': '서울<b>데이트</b>코스추천동묘구제시장<b>데이트</b>코스의마법사, 이백수지난번포스팅때<b>용답</b>역육교에서만나자전거라이딩으로동묘앞까지오는코스를소개한적이있다이후코스는인사동/동대문DDP/익선동등등..... ',
#    'bloggername': '노비의 부뚜막',
#    'bloggerlink': 'https://blog.naver.com/aussie_lee',
#    'postdate': '20170622'},
#   {'title': '장한평역꽃집 와이프선물 <b>데이트</b>선물 프로포즈꽃다발 보라꽃다발',
#    'link': 'https://blog.naver.com/weymiss?Redirect=Log&logNo=222623878826',
#    'description': '에게 #<b>데이트</b> 할때 피치색장미 #바이킹장미 핑크 #락스소국 핫핑크 #샹그릴라장미 연블루꽃 #델피늄... 성동구 <b>용답</b>중앙길50 1층 늘봄날 5호선 답십리역 6번출구 3분거리 2호선 <b>용답</b>역 출구하나 3분거리... ',
#    'bloggername': '답십리역꽃집 늘봄날플라워 장한평꽃집 한양대역꽃집',
#    'bloggerlink': 'https://blog.naver.com/weymiss',
#    'postdate': '20220117'},
#   {'title': '서울 장안동 <b>용답</b>동 맛집 &quot;<b>용답</b> 기사식당&quot;',
#    'link': 'https://blog.naver.com/kimd92?Redirect=Log&logNo=221314413857',
#    'description': '기사식당이라 <b>데이트</b>엔 어울리지 않지만 제가 매주 가자고 졸라서 오빠가 따라가주는 식당입니당 벌써 다섯번?정도는 간 것 같아요. 맛있으면서 괜히 그래 위 사진은 블로그를 하기 전이라 기록용으로만 남긴... ',
#    'bloggername': '도야미의 일상이야기',
#    'bloggerlink': 'https://blog.naver.com/kimd92',
#    'postdate': '20180707'},
#   {'title': '[지난일상] 밀린일상 / 2019년 8월 / 직딩 / <b>용답</b> / 곱창... ',
#    'link': 'https://blog.naver.com/redrabbit_?Redirect=Log&logNo=222057338691',
#    'description': '천호 <b>데이트</b> 천호 맛집이라던 안녕식당웨이팅 없이 입성 하고 ㅋㅋㅋㅋ 맛은 생각보다 걍 쏘쏘했는데 짬뽕은 맛있었음 소화시킬 겸 아트박스였나? 구경하는데 거기에 있던 펜인데 넘 귀여움...ㅠㅠ 하나... ',
#    'bloggername': '.',
#    'bloggerlink': 'https://blog.naver.com/redrabbit_',
#    'postdate': '20200811'},
#   {'title': '지양이랑 성수 <b>데이트</b>',
#    'link': 'https://blog.naver.com/qpalskdj11?Redirect=Log&logNo=222580587507',
#    'description': '지양이와 <b>데이트</b> 쉘위..? 나의 영원한 룸메 지양이의 자취방을 보고자 일부로 성수로 갔다 지양이의 집... 내려서 <b>용답</b>으로 가는 전철로 갈아타야한다 안그러면 한양대에 내려서 엄청난 오르막길을 ..겪어야한다... ',
#    'bloggername': '편식왕입니다',
#    'bloggerlink': 'https://blog.naver.com/qpalskdj11',
#    'postdate': '20211128'},
#   {'title': '엄마랑 병원<b>데이트</b>',
#    'link': 'https://blog.naver.com/father2223?Redirect=Log&logNo=222533679358',
#    'description': '기름 넣고 세차하고 정릉 가서 엄마랑 은행 볼 일 보고 병원<b>데이트</b> 강남 대로를 쭉쭉~ 깜빡이를 키면... 신답, <b>용답</b>, 용두동, 신설동, 이화동, 명륜동, 성북동 ㅎ &quot;참 오랜만에 서울 시내관광을 하네~&quot; 엄마가 참... ',
#    'bloggername': '안녕하세요? 국민의 힘 부천시의원 남미경입니다',
#    'bloggerlink': 'https://blog.naver.com/father2223',
#    'postdate': '20211011'},
#   {'title': '독서 / <b>용답</b> / <b>용답</b>코스 / 73명품 도야지 / 피자스쿨 / 청계천... ',
#    'link': 'https://blog.naver.com/redrabbit_?Redirect=Log&logNo=221677401594',
#    'description': '겸 <b>용답</b>초 돌면서 얘기함 얘기 해도해도 할말이 많은 것 보면 신기 집 와서 문득 엘베 거울을 보는데... 아쉽다 10월 17일 조윤선이랑 <b>용답</b> 코스로 조짐 <b>용답</b> 코스란 로데오곱창, 잉어빵, 복권, 파바 코스인데 1차... ',
#    'bloggername': '.',
#    'bloggerlink': 'https://blog.naver.com/redrabbit_',
#    'postdate': '20191014'},
#   {'title': '<b>용답</b>역먹자골목 <b>용답</b>동셰프포차',
#    'link': 'https://blog.naver.com/mcar5455?Redirect=Log&logNo=220606192347',
#    'description': '<b>용답</b>동에있는 셰프포차에서 <b>데이트</b>하기 신랑이 요기가끔 다녀오면..맛있었다고 함께가보자고하더라구욤.. 둘이 한잔하러나가기 쉽진않고 한번기회있어외출하면 어디갈곳도많고ㅋㅋㅋ 우리가오는곳은... ',
#    'bloggername': '장안평중고차시장',
#    'bloggerlink': 'https://blog.naver.com/mcar5455',
#    'postdate': '20160123'},
#   {'title': '서울 가볼만한곳 청계천, 응봉산 외 봄꽃 개화현황(03/27)',
#    'link': 'https://blog.naver.com/castpd?Redirect=Log&logNo=222684754079',
#    'description': '청계천 매화거리(하동매실거리) - <b>용답</b>역 2번출구 서울에서 매화가 유명한 곳으로 봉은사 홍매화... https://tv.naver.com/v/25887490 야경명소, 개나리축제, 야외 <b>데이트</b>장소로 유명한 서울 가볼만한곳 응봉산의... ',
#    'bloggername': '치부르의 여행 이야기',
#    'bloggerlink': 'https://blog.naver.com/castpd',
#    'postdate': '20220328'},
#   {'title': '서울 <b>데이트</b> 코스 봄꽃 명소 5곳',
#    'link': 'https://blog.naver.com/junsnet?Redirect=Log&logNo=222272807316',
#    'description': '청계천 하동매실거리 주소: 서울 성동구 <b>용답</b>동 2호선 <b>용답</b>역 2번 출구에서 400m 서울 <b>데이트</b> 코스 봄꽃 명소 청계천 하동 매실 거리는 백매화와 홍매화 그리고 담양 대나무가 심어져 있고, 천변에 매화가... ',
#    'bloggername': '싱글벙글 길가람',
#    'bloggerlink': 'https://blog.naver.com/junsnet',
#    'postdate': '20210312'},
#   {'title': '광양매화축제 대신 서울에서 매화보며 봄꽃 산책 <b>데이트</b>',
#    'link': 'https://blog.naver.com/ssong8985?Redirect=Log&logNo=220661109549',
#    'description': '청계천 신답역~<b>용답</b>역 구간이라니, 우리집에서 가깝구나야! 당장 출동! ▲ 매화가 몽실몽실 넘나이쁜것... 신답역에서 → <b>용답</b>역 방향으로 청계천을 오른쪽에 두고 걷는 중. 이 쪽 방향만 매화거리 이구요... ',
#    'bloggername': '한이의 놀 궁리',
#    'bloggerlink': 'https://blog.naver.com/ssong8985',
#    'postdate': '20160321'},
#   {'title': '답십리역 맛집-갈비명가이상 답십리점 내돈내산, 솔직후기',
#    'link': 'https://blog.naver.com/parkjm0307?Redirect=Log&logNo=222634406284',
#    'description': '내돈내산 #답십리꽃등심 #답십리회식 #답십리고기 #답십리소고기 #솔직후기 #답십리맛집 #맛집후기 #맛집솔직후기 #20대부부<b>데이트</b> #내돈내산 #일상 #<b>용답</b>역맛집 #<b>용답</b>역소고기 #<b>용답</b>역회식 #답십리<b>데이트</b>',
#    'bloggername': '뚜룹이네 일상',
#    'bloggerlink': 'https://blog.naver.com/parkjm0307',
#    'postdate': '20220129'},
#   {'title': '별미곱창 / <b>용답</b>양꼬치 / 핸드폰교체 / 오빠커플 / 10층한우... ',
#    'link': 'https://blog.naver.com/redrabbit_?Redirect=Log&logNo=221840408291',
#    'description': '갈까하다가 <b>용답</b>양꼬치 집에 갔다 여기 양갈비 넘나 맛있음 오랜만에 먹으니까 더 존맛탱이더라 ㅋㅋㅋ 새로운 메뉴였던 혈관꼬치는 좀 별로였지만 양갈비 맛있었으니까 괜츈 3월 4일 핸드폰 바꿔야되는데... ',
#    'bloggername': '.',
#    'bloggerlink': 'https://blog.naver.com/redrabbit_',
#    'postdate': '20200306'},
#   {'title': '답십리/<b>용답</b> 맛집-막창클럽',
#    'link': 'https://blog.naver.com/darnimi07?Redirect=Log&logNo=20202155659',
#    'description': '별님이 엄마한테 맡기고 간만에 준수랑 <b>데이트</b>!! 아가띠안하고 맨몸으로 돌아다니니 날아다닐듯 ㅋㅋ 가야지가야지 생각해뒀던 집앞 막창클럽! 별님이를 대리고 한번 갈볼랬는데 아직 담배피는 사람들이... ',
#    'bloggername': '달님별님뭉게구름 :-)',
#    'bloggerlink': 'https://blog.naver.com/darnimi07',
#    'postdate': '20131230'},
#   {'title': '서울 봄꽃길 여행 나들이 / 지하철 꽃구경 / <b>데이트</b>코스 추천',
#    'link': 'https://blog.naver.com/seoultrip1?Redirect=Log&logNo=220338161430',
#    'description': '<b>데이트</b>코스로도 추천해드릴게요!! ^^ 서울나들이 / <b>데이트</b>코스 / 지하철 꽃구경 봄꽃길 여행 소중한... (중곡,중화,수락산,장한평,<b>용답</b>) 용마폭포공원 / 개나리, 진달래, 벚꽃 (용마산) 서울창포원 / 붓꽃, 꽃창포... ',
#    'bloggername': '마로의 일상',
#    'bloggerlink': 'https://blog.naver.com/seoultrip1',
#    'postdate': '20150422'},
#   {'title': '늘봄날플라워 왕십리꽃집 한양대꽃집 미니꽃다발 <b>데이트</b>꽃다발',
#    'link': 'https://blog.naver.com/weymiss?Redirect=Log&logNo=222416653944',
#    'description': '특별한날이 아니여도 외국처럼 꽃문화가 생활이 되었으면 하길바라며 <b>데이트</b>갈때,퇴근후... 평일 11:00~08:00 주말 12:00~06:00(유동적) 일요일휴무 주소 성동구 <b>용답</b>중앙길50 1층 전화번호 ***.****.**** 인스타그램... ',
#    'bloggername': '답십리역꽃집 늘봄날플라워 장한평꽃집 한양대역꽃집',
#    'bloggerlink': 'https://blog.naver.com/weymiss',
#    'postdate': '20210701'},
#   {'title': '남산타워, 남산 둘레길 코스 따라 서울 야경 탐구생활',
#    'link': 'https://blog.naver.com/iamromy?Redirect=Log&logNo=222536159311',
#    'description': '남산만큼 서울 <b>데이트</b> 장소로 손색이 없는 곳도 드물다. 꽁냥꽁냥한 커플들의 사랑 맹세가 담긴... 촬영지 <b>용답</b>역 육교 서울 등산코스 아차산 용마산 망우산 서울 종로 익선동 한옥거리 수제맥주 비 오는 날... ',
#    'bloggername': '여행 크리에이터 Romy의 내멋대로 여행이야기...',
#    'bloggerlink': 'https://blog.naver.com/iamromy',
#    'postdate': '20211013'},
#   {'title': '여자친구꽃다발 <b>데이트</b>꽃다발 동대문꽃집 제기동꽃집... ',
#    'link': 'https://blog.naver.com/ooooba?Redirect=Log&logNo=222604253512',
#    'description': '여자친구꽃다발 <b>데이트</b>꽃다발 동대문꽃집 제기동꽃집 마장동꽃집 용두동꽃집 종로꽃집에 대한... 용두역꽃집 <b>용답</b>역꽃집 신답역꽃집 신설동꽃집 제기동꽃집 답십리초꽃집 동대문구청꽃집... ',
#    'bloggername': '동대문 홈플러스 꽃집 행복플라워 블로그',
#    'bloggerlink': 'https://blog.naver.com/ooooba',
#    'postdate': '20211225'},
#   {'title': '서울 야경 맛집 : 응봉산 팔각정 후기 (feat. 주차)',
#    'link': 'https://blog.naver.com/minijiny0728_?Redirect=Log&logNo=222700372070',
#    'description': '2호선 <b>용답</b>역 2번 출구부터 살곶이 체육공원 옆길 쪽으로 걸어가시는 거 추천드려요 연인과 손잡고... 너무 좋아유 응봉역 주차장 요금 5분 100원 1시간 1200원 서울 야경 맛집이에요 ㅠㅠ 커플 <b>데이트</b>로 강추 드려요 !',
#    'bloggername': '찌니와 설레는 데이트',
#    'bloggerlink': 'https://blog.naver.com/minijiny0728_',
#    'postdate': '20220414'},
#   {'title': '3월 지금 가볼만한곳 서울 매화 청계천 하동매실거리 홍매화... ',
#    'link': 'https://blog.naver.com/homibike?Redirect=Log&logNo=222679985525',
#    'description': '서울 <b>데이트</b> 코스 추천 사진 찍기 좋은곳 3. 사근<b>용답</b>인도교-드라마 도깨비촬영지 서울특별시 성동구 사근동 235-1 3. 청계천 드라마 도깨비 촬영지 사근<b>용답</b>간인도교 <b>용답</b>역에서 사근동으로 갈 수 있는... ',
#    'bloggername': '호미숙 자전거여행-사진여행',
#    'bloggerlink': 'https://blog.naver.com/homibike',
#    'postdate': '20220322'},
#   {'title': '[주말#:]<b>데이트</b>?ㅋㅋ비오는 날,영화 암살관람! 그리고 손글씨... ',
#    'link': 'https://blog.naver.com/omang_?Redirect=Log&logNo=220433855203',
#    'description': '불은 꺼져있고 닫혀있음 없어진건지, 공사중인건지 [<b>용답</b>동 등촌샤브샤브]아시는분 알면 비덧부탁해요 ㅋㅋㅋㅋㅋㅋㅋㅋ 그럼 짬뽕으로 고고씽 <b>용답</b>역 앞에 뽕앤돈스라고 새로 생겨서 가볼라고 했더니 22... ',
#    'bloggername': '비비드망의 발랄한 일상 블로그♬',
#    'bloggerlink': 'https://blog.naver.com/omang_',
#    'postdate': '20150728'},
#   {'title': '서울 매화구경 할만한 곳/청계천 하동매실거리 매화군락지',
#    'link': 'https://blog.naver.com/hanifuni?Redirect=Log&logNo=222685274376',
#    'description': '촬영 청계천 하동 매실거리는 2006년 경남 하동군이 <b>용답</b>역에서 신답역 구간 청계천 주변에 350그루... <b>데이트</b>하는 연인들. 취재를 나온 방송국 사람들. 사진작가들을 비롯해 저마다 작은 매화꽃을 담기 위해... ',
#    'bloggername': '여행&힐링 이야기',
#    'bloggerlink': 'https://blog.naver.com/hanifuni',
#    'postdate': '20220328'},
#   {'title': '7월 한달의 일상 (분량 짱 많음 스압주의)',
#    'link': 'https://blog.naver.com/gaeun6475?Redirect=Log&logNo=222459972171',
#    'description': '2021.7월 첫째주 (2021.7.2~2021.7.3) 2021.7.2 <b>용답</b>역 청계천 너무 예뻐 딱 1학기 기말고사가 끝난 날이다 !!... 엄마랑 <b>데이트</b> 하고 바로 수학으로 뛰어감...ㅎㅎ 2021.7.21 드디어 미뤄졌던 사회경시대회 하는 날임 !!... ',
#    'bloggername': 'You are my Celebrity_♥',
#    'bloggerlink': 'https://blog.naver.com/gaeun6475',
#    'postdate': '20210807'},
#   {'title': '답십리꽃집 여자친구와 3000일기념일꽃다발 준비하신... ',
#    'link': 'https://blog.naver.com/weymiss?Redirect=Log&logNo=222684945777',
#    'description': '아니여도 <b>데이트</b>갈때 소소하게 서프라이즈로 얼마나 갬동갬동 하겠냐구요 다음에 만나요... 성동구 <b>용답</b>중앙길50 1층 늘봄날 5호선 답십리역 6번출구 3분거리 2호선 <b>용답</b>역 출구하나 3분거리 (단비어린이집... ',
#    'bloggername': '답십리역꽃집 늘봄날플라워 장한평꽃집 한양대역꽃집',
#    'bloggerlink': 'https://blog.naver.com/weymiss',
#    'postdate': '20220328'},
#   {'title': '내가 찾은 서울 벚꽃명소, 벚꽃구경 장소',
#    'link': 'https://blog.naver.com/emem0583?Redirect=Log&logNo=222695659953',
#    'description': '5.<b>용답</b>역 청계천 여긴 찐으로 우연히 찾은 <b>용답</b>역에서 나오자마자 있는 청계천 산책로인데 벚꽃 나무도... 동대문 역사문화공원 DDP 엄청난 명소는 아니지만 <b>데이트</b>하러 동대문와서 인증샷 찍기 좋고 제일... ',
#    'bloggername': 'NICE DAY',
#    'bloggerlink': 'https://blog.naver.com/emem0583',
#    'postdate': '20220408'},
#   {'title': '2020년 상반기 황금연휴 / 따릉이<b>데이트</b> / 호캉스 / 코로나',
#    'link': 'https://blog.naver.com/sy170416?Redirect=Log&logNo=221943957222',
#    'description': '싶은 마음에 나랑 연욱이는 4일 내내 집콕하는 것보다 이틀은 집근처에서 <b>데이트</b> , 이틀은 집콕 하기로... 한창 쉬다가 또 그대로 쭈욱 밟아 1시간이 다 되어가기 때문에ㅋㅋ 따릉이 반납하러 <b>용답</b>역까지! 예전엔... ',
#    'bloggername': '일상',
#    'bloggerlink': 'https://blog.naver.com/sy170416',
#    'postdate': '20200503'},
#   {'title': '숲길, 같이 걸을래요?',
#    'link': 'https://blog.naver.com/xingf?Redirect=Log&logNo=222523330037',
#    'description': '걸으며 <b>데이트</b>하는 연인들의 장소가 되었다. 항동 철길을 따라 걸으면 푸른 수목원으로 들어가는... 하동 매실 거리 <b>용답</b>역을 나오면 청계천변을 따라 하얀 눈꽃이라도 맞은 듯 하얀 매화꽃들이 거리를 수놓고... ',
#    'bloggername': '블루몽kiss',
#    'bloggerlink': 'https://blog.naver.com/xingf',
#    'postdate': '20211001'},
#   {'title': '[답십리맛집] 매콤한 닭갈비와 파전을 한번에 먹을 수 있는... ',
#    'link': 'https://blog.naver.com/dustn9240?Redirect=Log&logNo=222365152806',
#    'description': '#조선닭갈비 #답십리맛집 #<b>용답</b>맛집 #오호선맛집 #닭갈비 #닭갈비맛집 #동네맛집 #답십리동네맛집 #서이추환영 #주말 #일상블로그 #<b>데이트</b> #답십리 #<b>용답</b> #답십리파전 #답십리닭갈비 #닭갈비배달 #맛집추천... ',
#    'bloggername': '뚜비뚜비 욘뚜비ღ',
#    'bloggerlink': 'https://blog.naver.com/dustn9240',
#    'postdate': '20210524'},
#   {'title': '우중에 청계천 산책 에서 만난 붓들레아 여름 라일락꽃',
#    'link': 'https://blog.naver.com/sunsun1890?Redirect=Log&logNo=222044378725',
#    'description': '빗방울이 많이는 아니지만 떨어지는 가운데 아이와 할머니와의 <b>데이트</b> 물고기가 있나 보네요. 뜰채를 가지고 노는 아이네요. <b>용답</b>역 근처에서 도깨비 촬영을 했나 봅니다. <b>용답</b>역 바로 앞에 <b>용답</b> 나들목교를... ',
#    'bloggername': '해피니스의 맛있는 감성 여행~~',
#    'bloggerlink': 'https://blog.naver.com/sunsun1890',
#    'postdate': '20200728'},
#   {'title': '양이 엄청 푸짐한 답십리맛집 홍춘천치즈닭갈비',
#    'link': 'https://blog.naver.com/bowoori7777?Redirect=Log&logNo=222675806429',
#    'description': '성동구 <b>용답</b>중앙15길 15 예약문의: 0507 - 1304 - 8427 포장, 배달, 국민지원금 사용가능 5호선 답십리역... 이쁜 조명들이 많아서 닭갈비집인데도 불구하고 아늑하고 감성적인 느낌도 더해져 <b>데이트</b>코스로도 오기... ',
#    'bloggername': '구움뱅이 맛집',
#    'bloggerlink': 'https://blog.naver.com/bowoori7777',
#    'postdate': '20220318'},
#   {'title': '청계천 매화 하동매실거리 이쁘네! (서울봄꽃♥)',
#    'link': 'https://blog.naver.com/hari33?Redirect=Log&logNo=222277247990',
#    'description': '퇴근 후 헤롱모드로 민아언니와 <b>데이트</b>~~♥ 매화도 이쁘고 하늘도 이쁘고 봄햇살은 따뜻하고 언니랑 <b>데이트</b>도 즐겁고~ <b>용답</b>역에서 신답역으로 이어지는 청계천 매화 하동매실거리 <b>용답</b>역에서 성수역... ',
#    'bloggername': '엄마의 꿈&여행 - story 2',
#    'bloggerlink': 'https://blog.naver.com/hari33',
#    'postdate': '20210316'},
#   {'title': '답십리 카페 떼루와 군고구마 대박 배달 포장 <b>데이트</b>',
#    'link': 'https://blog.naver.com/sslove0826?Redirect=Log&logNo=222182881197',
#    'description': '주소 : 서울시 성동구 <b>용답</b>동 14-13 1층 떼루와 크리스마스 이벤트등도 다양하게하고 연말 크리스마스... 나와서 다행히 날씨가 안추워서 벤치에앉아<b>데이트</b>하곤하는데 군고구마는 진짜 군고구마가 들어있어서... ',
#    'bloggername': '봉구님의블로그',
#    'bloggerlink': 'https://blog.naver.com/sslove0826',
#    'postdate': '20201224'},
#   {'title': '220319 부지런한 화도함의 하루',
#    'link': 'https://blog.naver.com/hamdohwa?Redirect=Log&logNo=222678013828',
#    'description': '엄마랑 <b>데이트</b> 성공적. 각자 다른 포즈  용감한 함깜뜨 신난 함깜뜨 아, 하동매실거리 매화 구경은 <b>용답</b>역 2번출구에서 오른쪽으로 걸어가다보면 나옵니다  호떡 구매 후 차로 돌아가는 길 엄마 집에 모셔다... ',
#    'bloggername': '옥수동 함씨',
#    'bloggerlink': 'https://blog.naver.com/hamdohwa',
#    'postdate': '20220320'},
#   {'title': '여자친구꽃다발 <b>데이트</b>꽃다발 화이트크리스마스 동대문꽃집... ',
#    'link': 'https://blog.naver.com/ooooba?Redirect=Log&logNo=222603175983',
#    'description': '#크리스마스꽃다발 #크리스마스이브꽃다발 #여자친구꽃다발 #<b>데이트</b>꽃다발 #화이트크리스마스... 용두역꽃집 <b>용답</b>역꽃집 신답역꽃집 신설동꽃집 제기동꽃집 답십리초꽃집 동대문구청꽃집 동대문보건소꽃집... ',
#    'bloggername': '동대문 홈플러스 꽃집 행복플라워 블로그',
#    'bloggerlink': 'https://blog.naver.com/ooooba',
#    'postdate': '20211223'},
#   {'title': "[서울 <b>데이트</b>코스 - 걷고 싶은길 탐방] 1탄 도심속 하천 '청계천'",
#    'link': 'https://blog.daum.net/hyejung114/511',
#    'description': '(토) 오후 4시 장 소 : 청계천 경 로 : 2호선 <b>용답</b>역 1번 출구 ~ 청계천 끝까지 걸음 시 간 : 보통 걸음으로... 자세한 등축제 사진은 ☞ [서울 <b>데이트</b> 코스] 2011년 제3회 청계천 등축제에 다녀오다. ☜ 에서 확인하실... ',
#    'bloggername': '달래 블로그',
#    'bloggerlink': 'https://blog.daum.net/hyejung114',
#    'postdate': '20111129'},
#   {'title': '청계천 매화거리 <b>데이트</b> 가실까요?.',
#    'link': 'https://blog.naver.com/ald8949?Redirect=Log&logNo=220968503788',
#    'description': '요즘 화창한 봄날!!~~ 서울에서 가장 먼저 꽃소식을 전하는 청개천 매화거리는 매년 3월초부터 청개천변 <b>용답</b>역과 신답역 사이에 조성된 매화거리 라네요.. 가족과 친구 연인과 손잡고 <b>데이트</b>를 즐길수 있는... ',
#    'bloggername': '"올림픽파크 포레온"',
#    'bloggerlink': 'https://blog.naver.com/ald8949',
#    'postdate': '20170327'}],
#  'place': [{'eventTarget': 'placeDesc',
#    'placeId': '36259223',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '장성식당',
#    'address': '서울특별시 성동구 용답중앙길 81',
#    'latitude': '37.5628333',
#    'longitude': '127.054325',
#    'tel': '02-2249-6322',
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '1443457960',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '용답깨비곱창',
#    'address': '서울특별시 성동구 용답19길 5',
#    'latitude': '37.5629061',
#    'longitude': '127.0516325',
#    'tel': '02-3394-6595',
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '33028144',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '승수네왕십리곱창',
#    'address': '서울특별시 성동구 용답19길 3 1층',
#    'latitude': '37.5627352',
#    'longitude': '127.051515',
#    'tel': '0507-1312-2458',
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '1281841330',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '하동매실거리',
#    'address': '서울특별시 성동구 용답동',
#    'latitude': '37.5636052',
#    'longitude': '127.0498276',
#    'tel': None,
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '1281841330',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '하동매실거리',
#    'address': '서울특별시 성동구 용답동',
#    'latitude': '37.5636052',
#    'longitude': '127.0498276',
#    'tel': None,
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '1543223045',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '카페앨리',
#    'address': '서울특별시 성동구 사근동12길 8',
#    'latitude': '37.5605823',
#    'longitude': '127.0483008',
#    'tel': None,
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '1627024011',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '선굼터 답십리점',
#    'address': '서울특별시 성동구 용답중앙15길 5',
#    'latitude': '37.5641378',
#    'longitude': '127.0530985',
#    'tel': '0507-1321-4552',
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '33860153',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '소문난순대국왕족발',
#    'address': '서울특별시 성동구 용답25라길 23',
#    'latitude': '37.5635646',
#    'longitude': '127.0530222',
#    'tel': '0507-1417-0207',
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '21405842',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '용답역2번출구',
#    'address': '서울특별시 성동구 사근동',
#    'latitude': '37.5626316',
#    'longitude': '127.0504816',
#    'tel': None,
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '1281841330',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '하동매실거리',
#    'address': '서울특별시 성동구 용답동',
#    'latitude': '37.5636052',
#    'longitude': '127.0498276',
#    'tel': None,
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '',
#    'searchEngine': 'naver',
#    'searchType': '',
#    'name': '사이사이샌드위치',
#    'address': '서울특별시 성동구 용답19길 9 ',
#    'latitude': '37.5631626',
#    'longitude': '127.0520246',
#    'tel': None,
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '19847411',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '통돼지 두루치기 김치찌개 전문점',
#    'address': '서울특별시 성동구 용답중앙15길 5-1',
#    'latitude': '37.5641631',
#    'longitude': '127.0531459',
#    'tel': '02-2248-6708',
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '13479403',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '용답역 2호선',
#    'address': '서울특별시 성동구 용답길 86',
#    'latitude': '37.5621781',
#    'longitude': '127.0508526',
#    'tel': '02-6110-1341',
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '20888344',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '소문난보배곱창',
#    'address': '서울특별시 성동구 용답19길 4-1',
#    'latitude': '37.562699',
#    'longitude': '127.051721',
#    'tel': '02-2244-6822',
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '1281841330',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '하동매실거리',
#    'address': '서울특별시 성동구 용답동',
#    'latitude': '37.5636052',
#    'longitude': '127.0498276',
#    'tel': None,
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '1945652251',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '한우갈비짝',
#    'address': '서울특별시 성동구 용답동 12-23',
#    'latitude': '37.5633318',
#    'longitude': '127.0536668',
#    'tel': '0507-1344-0369',
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '11664007',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '봉은사',
#    'address': '서울특별시 강남구 봉은사로 531 봉은사',
#    'latitude': '37.5149197',
#    'longitude': '127.0576546',
#    'tel': '0507-1429-4800',
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '',
#    'searchEngine': 'naver',
#    'searchType': '',
#    'name': '용답 뚝방길',
#    'address': '서울특별시 성동구 사근동 235-1',
#    'latitude': '37.5620927',
#    'longitude': '127.0504054',
#    'tel': None,
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '1281841330',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '하동매실거리',
#    'address': '서울특별시 성동구 용답동',
#    'latitude': '37.5636052',
#    'longitude': '127.0498276',
#    'tel': None,
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '33028144',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '승수네왕십리곱창',
#    'address': '서울특별시 성동구 용답19길 3',
#    'latitude': '37.5627352',
#    'longitude': '127.051515',
#    'tel': '02-2244-2458',
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '1443457960',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '용답깨비곱창',
#    'address': '서울특별시 성동구 용답19길 5',
#    'latitude': '37.5628808',
#    'longitude': '127.0516547',
#    'tel': '02-3394-6595',
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '1281841330',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '하동매실거리',
#    'address': '서울특별시 성동구 용답동',
#    'latitude': '37.5636052',
#    'longitude': '127.0498276',
#    'tel': None,
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '13479403',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '용답역 2호선',
#    'address': '서울특별시 성동구 용답길 86',
#    'latitude': '37.5621786',
#    'longitude': '127.0508533',
#    'tel': '02-6110-1341',
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '1281841330',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '하동매실거리',
#    'address': '서울특별시 성동구 용답동',
#    'latitude': '37.5636052',
#    'longitude': '127.0498276',
#    'tel': None,
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '1508340572',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '티거쉽',
#    'address': '서울특별시 송파구 송파대로 366 지하 1층',
#    'latitude': '37.5007599',
#    'longitude': '127.1116822',
#    'tel': '0507-1306-4249',
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '11664007',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '봉은사',
#    'address': '서울특별시 강남구 봉은사로 531 봉은사',
#    'latitude': '37.5149197',
#    'longitude': '127.0576546',
#    'tel': '0507-1429-4800',
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '35559518',
#    'searchEngine': 'naver',
#    'searchType': 'P',
#    'name': '경남기업',
#    'address': '서울특별시 동대문구 황물로 168',
#    'latitude': '37.565245',
#    'longitude': '127.056365',
#    'tel': None,
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '11664007',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '봉은사',
#    'address': '서울특별시 강남구 봉은사로 531 봉은사',
#    'latitude': '37.5149197',
#    'longitude': '127.0576546',
#    'tel': '0507-1429-4800',
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '605585253',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '마초쉐프 건대점',
#    'address': '서울특별시 광진구 능동로 125 2층 마초쉐프 건대점',
#    'latitude': '37.5421421',
#    'longitude': '127.0714072',
#    'tel': '0507-1344-8892',
#    'bookingUrl': 'https://booking.naver.com/booking/6/bizes/150030'},
#   {'eventTarget': 'placeDesc',
#    'placeId': '1281841330',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '하동매실거리',
#    'address': '서울특별시 성동구 용답동',
#    'latitude': '37.5636052',
#    'longitude': '127.0498276',
#    'tel': None,
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '12261493',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '창덕궁',
#    'address': '서울특별시 종로구 율곡로 99',
#    'latitude': '37.5826041',
#    'longitude': '126.9919376',
#    'tel': '02-3668-2300',
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '36668856',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '갈비명가이상 답십리점',
#    'address': '서울특별시 동대문구 천호대로 327',
#    'latitude': '37.5645078',
#    'longitude': '127.0563991',
#    'tel': '0507-1433-8202',
#    'bookingUrl': 'https://booking.naver.com/booking/6/bizes/345765'},
#   {'eventTarget': 'placeDesc',
#    'placeId': '317542230',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '응봉산 팔각정',
#    'address': '서울특별시 성동구 응봉동',
#    'latitude': '37.5478769',
#    'longitude': '127.0298879',
#    'tel': None,
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '1281841330',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '하동매실거리',
#    'address': '서울특별시 성동구 용답동',
#    'latitude': '37.5636052',
#    'longitude': '127.0498276',
#    'tel': None,
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '1281841330',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '하동매실거리',
#    'address': '서울특별시 성동구 용답동',
#    'latitude': '37.5636052',
#    'longitude': '127.0498276',
#    'tel': None,
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '32084625',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '청계천생태학습장',
#    'address': '서울특별시 성동구 살곶이길 69',
#    'latitude': '37.5697518',
#    'longitude': '127.0450871',
#    'tel': '02-2299-7997',
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '1079690221',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '홍춘천치즈닭갈비 답십리역로데오점',
#    'address': '서울특별시 성동구 용답중앙15길 15 2층',
#    'latitude': '37.5648062',
#    'longitude': '127.0539426',
#    'tel': '0507-1304-8427',
#    'bookingUrl': None},
#   {'eventTarget': 'placeDesc',
#    'placeId': '38643630',
#    'searchEngine': 'naver',
#    'searchType': 's',
#    'name': '떼루와 답십리점',
#    'address': '서울특별시 성동구 용답동 14-13',
#    'latitude': '37.5641544',
#    'longitude': '127.053428',
#    'tel': '02-3394-6317',
#    'bookingUrl': None}]}
